# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import date_calculator as dc

# %%
report = [0 for i in range(3)]
for i in range(3):
    report[i] = pd.read_excel('Report ('+str(i)+').csv')

# %%
report[0]
# Out:
#            요일구분    기준년도  2014년 2014년.1      2014년.2      2014년.3      2014년.4  \
# 0          요일구분    기준년도     합계   20세이하  21세이상~30세이하  31세이상~40세이하  41세이상~50세이하
# 1            합계    발생건수   9960     426         1346         2046         2377
# 2            합계  구성비(%)    100     4.3         13.5         20.5         23.9
# 3            합계    사망자수     52       0            7            9           13
# 4            합계    부상자수  16674     702         2307         3492         3909
# 5            합계    중상자수   1604      67          232          316          352
# 6            합계    경상자수   9002     348         1193         1840         2151
# 7            합계  부상신고자수   6068     287          882         1336         1406
# 8           수요일    발생건수   2017     103          328          420          444
# 9           수요일  구성비(%)    100     5.1         16.3         20.8           22
# 10          수요일    사망자수     17       0            4            5            1
# ...

# %%
report[0]['요일구분'] == '수요일'
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# Name: 요일구분, dtype: bool

# %%
report[1]['date'] = '0'
tmp1 = report[1].where(report[1]['요일구분'] == '수요일').dropna()['date']

tmp1 = pd.Series([dc.date_calculate('20140101', 8 * 1)], tmp1.index)
tmp1
# Out:
# 29    20140108
# 30    20140108
# 31    20140108
# 32    20140108
# 33    20140108
# 34    20140108
# 35    20140108
# dtype: object

# %%
series1 = pd.Series([dc.date_calculate('20140101', 8 * 1)], report[1].where(report[1]['요일구분'] == '수요일').dropna()['date'].index)
series2 = pd.Series([dc.date_calculate('20140102', 8 * 1)], report[1].where(report[1]['요일구분'] == '목요일').dropna()['date'].index)
pd.concat([series1, series2], axis = 0)
# Out:
# 29    20140108
# 30    20140108
# 31    20140108
# 32    20140108
# 33    20140108
# 34    20140108
# 35    20140108
# 36    20140109
# 37    20140109
# 38    20140109
# 39    20140109
# 40    20140109
# 41    20140109
# 42    20140109
# dtype: object

# %%
report[1]
# Out:
#            요일구분    기준년도  2014년 2014년.1      2014년.2      2014년.3      2014년.4  \
# 0          요일구분    기준년도     합계   20세이하  21세이상~30세이하  31세이상~40세이하  41세이상~50세이하
# 1            합계    발생건수  18561     743         2436         4013         4303
# 2            합계  구성비(%)    100       4         13.1         21.6         23.2
# 3            합계    사망자수    102       1           14           18           25
# 4            합계    부상자수  29085    1106         3776         6579         6686
# 5            합계    중상자수   2846      86          345          562          701
# 6            합계    경상자수  15581     588         2010         3369         3624
# 7            합계  부상신고자수  10658     432         1421         2648         2361
# 8           일요일    발생건수   1788      96          274          403          324
# 9           일요일  구성비(%)    100     5.4         15.3         22.5         18.1
# 10          일요일    사망자수      7       0            1            2            2
# ...

# %%
for i in (1,2):
    report[i]['date'] = 0
    series1 = pd.Series([dc.date_calculate('20140101', 8 * i)], report[i].where(report[i]['요일구분'] == '수요일').dropna()['date'].index)
    series2 = pd.Series([dc.date_calculate('20140102', 8 * i)], report[i].where(report[i]['요일구분'] == '목요일').dropna()['date'].index)
    series3 = pd.Series([dc.date_calculate('20140103', 8 * i)], report[i].where(report[i]['요일구분'] == '금요일').dropna()['date'].index)
    series4 = pd.Series([dc.date_calculate('20140104', 8 * i)], report[i].where(report[i]['요일구분'] == '토요일').dropna()['date'].index)
    series5 = pd.Series([dc.date_calculate('20140105', 8 * i)], report[i].where(report[i]['요일구분'] == '일요일').dropna()['date'].index)
    series6 = pd.Series([dc.date_calculate('20140106', 8 * i)], report[i].where(report[i]['요일구분'] == '월요일').dropna()['date'].index)
    series7 = pd.Series([dc.date_calculate('20140107', 8 * i)], report[i].where(report[i]['요일구분'] == '화요일').dropna()['date'].index)

    all_series = pd.concat([series1, series2, series3, series4, series5, series6, series7], axis=0)
    report[i]['date'] = all_series

dfa = report[1].dropna().sort_values(['date'])
#dfa[('date', '2014년')]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\Administrator\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5280)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5126)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20523)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20477)()
#
# KeyError: ('date', '2014년')
#
# During handling of the above exception, another exception occurred:
#
# ...
